# %%
# !pip install spacy

# !python -m spacy download en_core_web_sm

import spacy
nlp = spacy.load("en_core_web_sm")

# %%
import json

with open('jre_yt.json', 'r') as file:
    data = json.load(file)

# %%
# # Print the data
# data

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

def extract_names_and_titles(data):
    # Extract names from the 'guest' field
    guest_names = []
    for episode in data:
        if 'guest' in episode:
            guest_names.append(episode['guest'])

    
    # Extract names from the 'description' field using NER
    names_from_description = []
    for episode in data:
        if 'description' in episode:
            doc = nlp(episode['description'])
            for entity in doc.ents:
                if entity.label_ == "PERSON":
                    names_from_description.append(entity.text)
    
    # Extract titles and descriptions
    titles = []
    descriptions = []
    for episode in data:
        titles.append(episode['title'])
        descriptions.append(episode['description'])
    
    return guest_names, names_from_description, titles, descriptions

# %%
# Call the function to generate the lists
guest_names, names_from_description, titles, descriptions = extract_names_and_titles(data)

# %%
guest_names
# Out:
# ['Ron White',
#  'Adam Curry',
#  'Mike Tyson',
#  'Miley Cyrus',
#  'Duncan Trussell',
#  'Whitney Cummings & Annie Lederman',
#  'Nikki Glaser',
#  'David Blaine',
#  'Ali Macofsky',
#  'Tim Dillon',
#  'Ron Funches',
#  'Joey Diaz & Brian Redban',
#  'Rob Lowe',
#  'Josh Dubin & Jason Flom',
#  'Dr. Debra Soh',
#  'Mike Baker',
#  'David Choe',
#  'Nancy Panza',
#  'Post Malone',
#  'Dr. Bradley Garrett',
#  'Joe De Sena',
#  'Andrew Huberman',
#  'Ben Shapiro',
#  'Oliver Stone',
#  'George Knapp & Jeremy Corbell',
#  'Abigail Shrier',
#  'Peter Schiff',
#  'Bob Saget',
#  'James Nestor',
#  'Hannibal Buress',
#  'Alan Levinovitz',
#  'Josh Barnett',
#  'Russell Peters',
#  'James Lindsay',
#  'Brendan Schaub',
#  'Barbara Freese',
#  'Henry Cejudo',
#  'Justin Gaethje & Trevor Wittman',
#  'Brendan Schaub',
#  'Fight Companion',
#  'Alexander Volkanovski',
#  'Fight Companion',
#  'Angela Hill',
#  'Radio Rahim',
#  'Rashad Evans',
#  'Frankie Edgar',
#  'Rafael Lovato Jr',
#  'Kamaru Usman',
#  'Josh Thomson',
#  'Fight Companion',
#  'Max Holloway',
#  'Tony Hinchcliffe',
#  'Pavel Tsatsouline',
#  'Lil Duval',
#  'S.C. Gwynne',
#  'Michelle Wolf',
#  'Matt Farah',
#  'Glenn Villeneuve',
#  'Brendan Schaub',
#  'James Wilks & Chris Kresser',
#  'Firas Zahabi',
#  'Tim Dillon',
#  'Tulsi Gabbard & Jocko Willink',
#  'Zach Bitter',
#  'Chris Kresser Debunks "The Gamechangers" Documentary',
#  'Louie Psihoyos',
#  'Josh Homme',
#  'Paul Stamets',
#  'Ari Shaffir',
#  'Ari Shaffir',
#  'Malcolm Gladwell',
#  'RZA & Donnell Rawlings',
#  'Israel Adesanya',
#  'Donnell Rawlings',
#  'Pete Dominick',
#  'Ben Westhoff',
#  'Greg Fitzsimmons',
#  'Rick Baker',
#  'Edward Norton',
#  'Artie Lange',
#  'John Carmack',
#  'Alonzo Bodden',
#  'Justin Wren',
#  'Kyle Kulinski',
#  'Kevin Smith',
#  'Dave Leduc',
#  'Andrew Santino',
#  'Brian Grazer',
#  'Christopher Ryan',
#  'Edward Snowden',
#  'Bridget Phetasy',
#  'Richard Dawkins',
#  'Cameron Hanes',
#  'Brian Redban',
#  'Evander Holyfield',
#  'Dakota Meyer',
#  'Lenny Clarke',
#  'Cmdr. David Fravor & Jeremy Corbell',
#  'Nikki Glaser',
#  'Roseanne Barr',
#  'Sober October 3',
#  'Ari Shaffir',
#  'Sturgill Simpson & His Band',
#  'Mark Normand',
#  'Vinny Shoreman & Liam Harrison',
#  'The Black Keys',
#  'Rob Zombie',
#  'Sean Carroll',
#  'Dan Aykroyd',
#  'Nick Bostrom',
#  'David Sinclair',
#  'Fight Companion',
#  'Bill Burr',
#  'Neil deGrasse Tyson',
#  'Zuby',
#  'Steve Aoki',
#  'Andre Ward',
#  'Joseph LeDoux',
#  'Penn Jillette',
#  'Cedric Doumbe',
#  'Steven Rinella',
#  'Terence Crawford',
#  'John Nores',
#  'Everlast',
#  'Roy Wood Jr',
#  'Dan Crenshaw',
#  'Dan Hardy',
#  'Legion of Skanks',
#  'Jim Gaffigan',
#  'Fahim Anwar',
#  'Brendan Schaub',
#  'Tom Papa',
#  'Annie Lederman',
#  'Jean Jacques Machado',
#  'Bernie Sanders',
#  'Andy Ruiz',
#  'Brian Moses',
#  'Whitney Cummings',
#  'Mike Baker',
#  'Rico Verhoeven',
#  'Maynard James Keenan',
#  'Duncan Trussell',
#  'Aljamain Sterling',
#  'Dr. Cornel West',
#  'Ian Edwards',
#  'Andy Ngo',
#  'Reggie Watts',
#  'Robert Oberst',
#  'Yves Edwards',
#  'Eric Weinstein',
#  'Joey Diaz',
#  'Hotep Jesus',
#  'Will Harris',
#  'Abby Martin',
#  'Bob Lazar & Jeremy Corbell',
#  'Charlamagne tha God & Andrew Schulz',
#  'Ms Pat',
#  'Kevin Lee',
#  'David Pakman',
#  'Sober October 2019 Preview',
#  'Naval Ravikant',
#  'Eddie Bravo',
#  'Greg Fitzsimmons',
#  'Wiz Khalifa',
#  'Michelle Waterson',
#  'JD & John Witherspoon',
#  'Brendan Schaub',
#  'Tommy Chong',
#  'Ed Calderon',
#  'Laird Hamilton',
#  'Michael Malice',
#  'Annie Jacobsen',
#  'Neal Brennan',
#  'Phil Demers',
#  'Joe List',
#  'Tulsi Gabbard',
#  'Jamie Metzl',
#  'Andrew Santino',
#  'Lex Fridman',
#  'C.T. Fletcher',
#  'Bryan Callen',
#  'Eddie Izzard',
#  'Jon Reep',
#  'Rich Benoit',
#  'Anthony Jeselnik',
#  'Corey Anderson',
#  'Khalil Rountree Jr.',
#  'B',
#  'Graham Hancock',
#  'Russell Brand',
#  'Adam Conover',
#  'Jorge Masvidal',
#  'Brendan Schaub',
#  'Tom Papa',
#  'Herb Dean',
#  'Michael Yo',
#  'Jessimae Peluso',
#  'Kevin Hart',
#  'Gabrielle Reece',
#  'Ben Shapiro',
#  'Forrest Griffin, Clint Wattenberg & Dr. Duncan French',
#  'Luis J. Gomez',
#  'Ron Funches',
#  'Lindsey Fitzharris',
#  'Billy Corben',
#  'Lenny Clarke',
#  'Bryan Callen',
#  'Ron White',
#  'Gary Taubes & Stephan Guyenet',
#  'Kamaru Usman',
#  'Ben Anderson',
#  'Andrew Schulz',
#  'Timothy Denevi',
#  'Renée DiResta',
#  'Pat McNamara',
#  'Peter Hotez',
#  'Lennox Lewis & Russell Peters',
#  'David Wallace',
#  'Jack Dorsey, Vijaya Gadde & Tim Pool',
#  'Brendan Schaub',
#  'Steve Sweeney',
#  'David Lee Roth',
#  'Alex Jones Returns!',
#  'Dr. Phil',
#  'Ioan Grillo',
#  'Dave Foley & Paul Greenberg',
#  'Tim Dillon',
#  'Johann Hari',
#  'Donnell Rawlings',
#  'Bill Ottman',
#  'Andy Stumpf',
#  'Fight Companion',
#  'Pot Debate',
#  'Andrew Yang',
#  "Colin O'Brady",
#  'Rafinha Bastos',
#  'Tim Pool',
#  'Sam Harris',
#  'Forrest Galante',
#  'Travis Barker',
#  'Brian Redban',
#  'Sebastian Maniscalco',
#  'Jack Dorsey',
#  'TJ Dillashaw',
#  'Ben Greenfield',
#  'David Sinclair',
#  'Brian Cox',
#  'Fight Companion',
#  'Nick Di Paolo',
#  'Killer Mike',
#  'Richard Rawlings',
#  'Bari Weiss',
#  'Mike Tyson',
#  'Mike Baker',
#  'Brendan Schaub',
#  'Theo Von',
#  'Adam Greentree',
#  'Greg Fitzsimmons',
#  'Michael Shermer',
#  'Kelly Pavlik',
#  'Din Thomas',
#  'Jonathan Haidt',
#  'Jeff Novitzky',
#  'Jeff Novitzky',
#  'Joey Diaz',
#  'Bill Burr',
#  'Nimesh Patel',
#  'Gad Saad',
#  'Sir Roger Penrose',
#  "Ben O'Brien",
#  'Lawrence Lessig',
#  'Dr. Andrew Weil',
#  'Michael Bisping',
#  'Deontay Wilder',
#  'Shane Smith',
#  'David Lee Roth',
#  'Dr. Amit Goswami',
#  'Bas Rutten',
#  'Scott Sigler',
#  'Justin Wren',
#  'Douglas Rushkoff',
#  'JD Kelley',
#  'Stanley Krippner, Christopher Ryan',
#  'Bryan Callen',
#  'Dr. Steven Greer',
#  'Joey Diaz',
#  'Steven Rinella, Bryan Callen, Cam Edwards',
#  'Greg Fitzsimmons',
#  'Tom Segura',
#  'James "The Colossus" Thompson',
#  'Eddie Huang',
#  'Duncan Trussell',
#  'Joey Diaz',
#  'Doug Stanhope',
#  'Andrew Dice Clay',
#  'Bert Kreischer (Part 2)',
#  'Steve Volk',
#  'Neil Degrasse Tyson',
#  'Steve Rinella, Bryan Callen',
#  'Ian Edwards',
#  'Enson Inoue, Chuck Lidell',
#  'David Choe, Yoshi Obayashi',
#  'Alex Honnold',
#  'Melissa Etheridge',
#  'Ari Shaffir',
#  'Sam Sheridan',
#  'Dan Carlin',
#  '"Freeway" Rick Ross',
#  'Jacob Ward',
#  'Bert Kreischer',
#  'Bryan Callen',
#  'Andrew Dice Clay',
#  'Chael Sonnen',
#  'Michael Ruppert',
#  'Dom Irrera',
#  'Joey Diaz',
#  'Ari Shaffir (Part 2)',
#  'Shane Smith',
#  'Mike Dolce, Joey Diaz',
#  'Brian Redban',
#  'John Anthony West',
#  'Ari Shaffir',
#  'Bill Burr',
#  'Dom Irrera',
#  'Giorgio Tsoukalos',
#  'Adam Scorgie',
#  'Josh Barnett (Part 1)',
#  'Ari Shaffir (Part 1)',
#  'Eddie Ifft',
#  'Freeway Rick Ross',
#  'Tom Segura, Christina Pazsitzky',
#  'Joe Rogan Experience #206  Eddie Bravo',
#  'Joe Rogan Experience #205  Neal Brennan',
#  'Amy Schumer',
#  'Jim Jefferies',
#  'Dom Irrera',
#  'EverLast',
#  'Duncan Trussell',
#  'Duncan Trussell',
#  'David Goggins',
#  'Yves Edwards',
#  'Dr. Ben Goertzel',
#  'Tom Papa',
#  'Anthony Cumia',
#  'Ross Edgley',
#  'William von Hippel',
#  'Fred Morin & David McMillan',
#  'Eric Weinstein',
#  'Steven Rinella',
#  'Jake "The Snake" Roberts & Tony Hinchcliffe',
#  'Mike Ward & Pantelis',
#  'Jeff Ross & Dave Attell',
#  'Jordan Peterson',
#  'Miriam Nakamoto',
#  'Fight Companion',
#  'Fight Companion',
#  'Tom Segura & Sean Anders',
#  'Derren Brown',
#  'Michael Malice',
#  'Dale Earnhardt Jr.',
#  'Christina P',
#  'Sober October 2 Recap',
#  'Henry Cejudo & Eric Albarracin',
#  'Shane Dorian',
#  'Tony Hinchcliffe',
#  'Tyson Fury',
#  'Peter Boghossian & James Lindsay',
#  'Joey Diaz',
#  'Alex Honnold',
#  'Lex Fridman',
#  'Kyle Kulinski',
#  'Ari Shaffir',
#  'Justin Wren & Rafael Lovato Jr.',
#  'Marques Brownlee',
#  'Kelly Slater',
#  'Roseanne Barr',
#  'John Kavanagh & George Lockhart',
#  'Andrew Santino',
#  'Nick Kroll',
#  'Brendan Schaub',
#  'John Dudley',
#  'Everlast',
#  'Nikki Glaser',
#  'Dr. Rhonda Patrick',
#  'Sober October 2',
#  "Dom D'Agostino & Layne Norton",
#  'Chris Kresser & Dr. Joel Kahn',
#  'Teddy Atlas',
#  'Vinnie Paz',
#  'TJ Dillashaw & Duane Ludwig',
#  'Geoffrey Miller',
#  'Morgan Fallon',
#  'Nick Yarris',
#  'Eddie Bravo',
#  'Tulsi Gabbard',
#  'Elon Musk',
#  'Mareko Maumasi',
#  'Larry Sharpe',
#  'Diamond Dallas Page',
#  'Donald "Cowboy" Cerrone',
#  'Tom Papa',
#  'Mikhaila Peterson',
#  'Banachek',
#  'Valentine Thomas',
#  'Jerrod Carmichael & Jamar Neighbors',
#  'Bert Kreischer',
#  'Neil deGrasse Tyson',
#  'Chuck Palahniuk',
#  'Shooter Jennings',
#  'Jimmy Dore',
#  'Henry Rollins',
#  'Gaston Bolanos & Kirian Fitzgibbons',
#  'Mark DellaGrotte',
#  'Doug Duren & Bryan Richards',
#  'Macaulay Culkin',
#  'John Joseph',
#  'Sean Carroll',
#  'Felipe Esparza',
#  'Michael Scott Moore',
#  'Andrew Santino',
#  'Brendan Schaub & Bryan Callen',
#  'Dr. Debra Soh',
#  'Jeff Garlin',
#  'Peter Schiff',
#  'Doug Stanhope',
#  'Israel Adesanya',
#  'Candice Thompson',
#  'Josh Barnett',
#  'Tony Rock',
#  'Theo Von',
#  'Brendan Schaub',
#  'Joey Diaz',
#  'Jordan Peterson',
#  'Ted Nugent',
#  'Duncan Trussell',
#  'Firas Zahabi',
#  'Hamilton Morris',
#  'Ari Shaffir',
#  'Kyle Dunnigan',
#  'Dennis McKenna',
#  'Kyle Kingsbury',
#  'Daniel Straus & Joe Schilling',
#  'Dave Rubin',
#  'Adam Frank',
#  'Tom Papa',
#  'Ryan Sickler',
#  "Sean O'Malley & Tim Welch",
#  'Jesse Itzler',
#  'Erik Griffin',
#  'Candace Owens',
#  'Robert Schoch',
#  'Kevin Smith',
#  'Donnie Vincent',
#  'Cat Zingano',
#  'Fight Companion',
#  'Michael Pollan',
#  'Pierre',
#  'Ben Greenfield',
#  'Robin Black',
#  'Howard Bloom',
#  'Theo Von',
#  'Tim Kennedy',
#  'Steven Tyler',
#  'Big John McCarthy',
#  'Michael Chandler',
#  'Mike Baker',
#  'Matt Taibbi',
#  'Brian Redban',
#  'Cameron Hanes',
#  'Fight Companion',
#  'Abby Martin',
#  'Zach Bitter',
#  'Matthew Walker',
#  'Peter Attia',
#  'Kevin Lee',
#  'Sam Harris & Maajid Nawaz',
#  'Colion Noir',
#  'Michael Hunter',
#  'Alexander Gustafsson',
#  'Boyan Slat',
#  'Tom Segura',
#  'Matt Farah',
#  'Bas Rutten',
#  'Chris & Mark Bell',
#  'Liz Phair',
#  'Brendan Schaub',
#  'Christopher Ryan',
#  'Yves Edwards',
#  'Legion of Skanks',
#  'Todd Glass',
#  'TJ English & Joey Diaz',
#  'Vinny Shoreman & Liam Harrison',
#  'Pat Miletich',
#  'Brian Redban',
#  'Owen Benjamin & Kurt Metzger',
#  'Mary Lynn Rajskub',
#  'Daniele Bolelli',
#  'Andrew Santino',
#  'Yoel Romero & Joey Diaz',
#  'John Dudley',
#  'Bryan Callen',
#  'Brendan Schaub',
#  'Sturgill Simpson',
#  'Rory Albanese',
#  'Kyle Kulinski',
#  'Douglas Murray',
#  'Dom Irrera',
#  'Greg Fitzsimmons',
#  'Bret Weinstein & Heather Heying',
#  'David Goggins',
#  'Tony Hinchcliffe',
#  'Brendan Schaub',
#  'Jimmy Dore',
#  'Johann Hari',
#  'Phil Demers',
#  'Eddie Pepitone',
#  'Duncan Trussell',
#  'Matt Brown',
#  'Cameron Hanes',
#  'Steven Pinker',
#  'Joey Diaz',
#  'Steven Crowder & NotGay Jared',
#  'Jordan Peterson',
#  'Ben Greenfield',
#  'Michael Shermer',
#  'Rose Namajunas & Pat Barry',
#  'Whitney Cummings',
#  'Ben Askren',
#  'Mel Gibson & Dr. Neil Riordan',
#  'Danica Patrick',
#  'John Danaher',
#  'Eddie Huang & Jessica Rosenworcel',
#  'Fight Companion',
#  'Tyron Woodley',
#  'Tom Segura',
#  'Dan Harris & Jeff Warren',
#  'Tom Papa',
#  'Remi Warren',
#  'Jeff Novitzky',
#  'Jimmy Smith',
#  'Brian Redban',
#  'Nina Teicholz',
#  'Dr. Mark Gordon & Andrew Marr',
#  'Brendan Schaub & Bryan Callen',
#  'Eddie Bravo',
#  'Bret Weinstein',
#  'Dr. Rhonda Patrick',
#  'Neal Brennan',
#  'Stipe Miocic',
#  'Mick West',
#  'Duncan Trussell & Christopher Ryan',
#  'Dr. Shawn Baker',
#  'Chris Stapleton',
#  'Justin Wren',
#  'Doug Stanhope',
#  'Andy Stumpf',
#  'Brendan Schaub',
#  'Owen Smith',
#  'Bryan Callen',
#  'C.T. Fletcher',
#  'Brian Redban',
#  'JRE MMA Show #2 (Audio Only)',
#  'Krystyna Hutchinson & Corinne Fisher',
#  'Dan Carlin',
#  'JRE MMA Show #1',
#  'Brian Regan',
#  'Iliza Shlesinger',
#  'Billy Corgan',
#  'Fight Companion',
#  'Ari Shaffir, Bert Kreischer & Tom Segura',
#  'Paul Stamets',
#  'Chris Kresser',
#  'Sebastian Junger',
#  'Owen Benjamin',
#  'Colin Moriarty',
#  'Jamie Kilstein',
#  'Joey Diaz',
#  'Tom DeLonge',
#  'Adam Greentree',
#  'Courtney Dauwalter',
#  'Brian Redban',
#  'Greg Fitzsimmons',
#  'UFC Recap w/ Brendan Schaub',
#  'Bert Kreischer',
#  'Christina P',
#  'Eric Weinstein',
#  'Russell Brand',
#  'Amy Alkon',
#  'Bryan Fogel',
#  'Alonzo Bodden',
#  'Jim Norton',
#  'Whitney Cummings',
#  'Reggie Watts',
#  'Dave Smith',
#  'Cameron Hanes',
#  'Fight Companion',
#  'Brendan Schaub',
#  'Tom Papa',
#  'Brian Redban',
#  'James Damore',
#  'Cody Garbrandt & Urijah Faber',
#  'Ari Shaffir, Bert Kreischer & Tom Segura',
#  'Fight Companion',
#  'Jordan Peterson & Bret Weinstein',
#  'Hannibal Buress',
#  'W. Kamau Bell',
#  'Mayweather vs. McGregor Recap with Brendan Schaub',
#  'Sean Carroll',
#  'Peter Schiff',
#  'Mike Baker',
#  'Fight Companion',
#  'Joey Diaz   **Re',
#  'Fight Breakdown',
#  'Fight Companion',
#  'Fight Companion',
#  'Fight Companion',
#  'Fight Companion',
#  'Fight Companion',
#  'Bryan Callen',
#  'Bas Rutten & Mauro Ranallo',
#  'Hunter Maats',
#  'CES Review with Young Jamie',
#  '#WhoIsFat Weigh',
#  '#WhoIsFat Weigh',
#  'Fight Recap',
#  'Greg Fitzsimmons',
#  'Fight Breakdown',
#  'Brian Redban',
#  'Ron White',
#  'James Hetfield',
#  'Hank Shaw',
#  'Tom Segura',
#  'Joey Diaz',
#  'Kevin Smith',
#  'Fight Companion',
#  'Fight Companion',
#  'Tom Papa',
#  'Lee Camp',
#  'Jon Jones',
#  'Steven Rinella',
#  'Aubrey Marcus',
#  'Jordan Peterson',
#  'Shannon Briggs',
#  'Scott Adams',
#  'Steven Kotler',
#  'Graham Hancock & Randall Carlson',
#  'Brendan Schaub',
#  'End Of The World (from The Comedy Store)',
#  'Dave Rubin',
#  'John Dudley (Audio Only)',
#  'Christine Hassler',
#  'Joey Diaz',
#  'Wim Hof',
#  'Fight Companion',
#  'Kevin Ross & Gaston Bolanos',
#  'Duncan Trussell',
#  'Trevor Valle',
#  'Bryan Callen',
#  'Bryan Callen',
#  'Russell Peters',
#  'Brian Redban',
#  'Jesse Ventura',
#  'Fight Companion',
#  'Dan Bilzerian',
#  'Tony Hinchcliffe & Young Jamie',
#  'Tom Segura & Christina Pazsitzky',
#  'Louie Simmons',
#  'Adam Greentree',
#  'John Anthony West',
#  'Shane Mauss',
#  'George Perez',
#  'James Kingston',
#  'Fight Companion',
#  'Bryan Callen',
#  'Dan Carlin',
#  'Michael Shermer',
#  'TJ Dillashaw, Duane Ludwig & Bas Rutten',
#  'Andreas Antonopoulos',
#  'Tony Hinchcliffe',
#  'Fight Companion',
#  'Chris Kresser',
#  'Greg Fitzsimmons',
#  'Donald Cerrone',
#  'Fight Companion',
#  'Tom Papa',
#  'Josh Zepps',
#  'Gad Saad',
#  'Hannibal Buress',
#  'Louis Theroux',
#  'Dan Doty',
#  'Brian Redban',
#  'Vinny Shoreman',
#  'Fight Companion',
#  'Byron Bowers',
#  'Neal Brennan',
#  'Wayne Federman',
#  'Duncan Trussell',
#  'Twitter Q&A with Joe',
#  'Justin Wren',
#  'Jeremy Stephens',
#  'Bryan Callen',
#  'Eleanor Kerrigan',
#  'Chael Sonnen',
#  '#821 & Fight Companion',
#  'Milo Yiannopoulos',
#  'Brendan Schaub',
#  'Mike Schmidt',
#  'Jason Hairston & Brendan Burns',
#  'Cameron Hanes',
#  'Joe Schilling',
#  'Ari Shaffir',
#  'Shane Dorian',
#  'Russell Brand & Jim Breuer',
#  'Fight Companion',
#  'Fight Companion',
#  'Jim Breuer',
#  'Big Jay Oakerson',
#  'Aubrey Marcus',
#  'Gino & AJ, from Speedweed',
#  'Michael Wood, Jr.',
#  'Dave Smith',
#  'Steve Hofstetter',
#  'Sam Harris',
#  'Fight Companion',
#  'Joey Diaz & Lee Syatt',
#  'Tom Papa',
#  'Gary Johnson',
#  'Bobcat Goldthwait',
#  'Brendan Schaub & Bryan Callen',
#  'Alison Rosen',
#  'Alex & Allyson Grey',
#  'Josh Zepps',
#  'Ian Edwards',
#  'Miesha Tate',
#  'Whitney Cummings',
#  'Lewis, from Unbox Therapy',
#  'Steve Schirripa',
#  'Steve Maxwell',
#  'Dan Auerbach',
#  'Brendan Schaub',
#  'Eddie Huang',
#  'Wheeler Walker, Jr.',
#  'Dom Irrera',
#  'Brian Redban',
#  'John Dudley',
#  'Rick Doblin',
#  'Kevin Rose',
#  'Sturgill Simpson',
#  'Andrew Dice Clay & Joey Diaz',
#  'Ari Shaffir',
#  'Brian Redban',
#  'Adam Cropp',
#  'Greg Fitzsimmons',
#  'Brendan Schaub & Bryan Callen',
#  'Dr. Rhonda Patrick',
#  'Mark & Chris Bell',
#  'Eddie Bravo',
#  'Michael Shermer',
#  'Ian McCall, Brendan Schaub & Bryan Callen',
#  'Mike Baker',
#  'Gad Saad',
#  'Tovar Cerulli',
#  'Duncan Trussell',
#  'Action Bronson',
#  'Fight Companion',
#  'Robin Black',
#  'Bas Rutten',
#  'Doug Duren & Nathan Ihde',
#  'Cameron Hanes',
#  'Tom Papa',
#  'Gary Clark, Jr.',
#  'Fight Companion',
#  'Kyle Kingsbury',
#  'Daniele Bolelli',
#  'Brian Redban',
#  'Hannibal Buress',
#  'Mark Sisson',
#  'Doug Stanhope',
#  'Kip Andersen & Keegan Kuhn, producers of Cowspiracy',
#  'Carlos Condit & Erwan Le Corre',
#  'Jenny Johnson',
#  'Tony Hinchcliffe',
#  'TJ Kirk',
#  'Ari Shaffir',
#  'Tom Segura',
#  'Phil Demers',
#  'Aubrey Marcus',
#  'Joey Diaz',
#  'Thaddeus Russell',
#  'Duncan Trussell & Christopher Ryan',
#  'Molly Crabapple',
#  'Lance Armstrong',
#  'Peter Boghossian',
#  'Brendan Schaub & Bryan Callen',
#  'Brendan Schaub',
#  'Judah Friedlander',
#  'Whitney Cummings',
#  'Bert Kreischer',
#  'Demetrious Johnson',
#  'Jocko Willink',
#  'Fight Companion',
#  'Ceara Lynch',
#  'Bill Burr',
#  'Josh Zepps',
#  'Graham Hancock & Randall Carlson',
#  'Christina Sommers',
#  'Dana White & Tony Hinchcliffe (Audio Only)',
#  'Tony Hinchcliffe (Audio Only)',
#  'Eddie Bravo',
#  'Tait Fletcher & Andy Stumpf',
#  'Josh Olin',
#  'Christopher Ryan',
#  'Steve',
#  'Daniele Bolelli',
#  'Remi Warren',
#  'John Wayne Parr',
#  'Dave Rubin',
#  'Wim Hof',
#  'Brian Redban',
#  'Gavin McInnes',
#  'Steven Rinella',
#  'Steven Crowder',
#  'Michael Dowd',
#  'Brendan Schaub & Fight Companion ? (Part 2)',
#  'Brendan Schaub & Fight Companion ? (Part 1)',
#  'Brendan Schaub & Fight Companion ? (Part 2)',
#  'Brendan Schaub & Fight Companion ? (Part 1)',
#  'Tait Fletcher',
#  'Alonzo Bodden',
#  'Brian Redban',
#  'Milo Yiannopoulos',
#  'Honey Honey (Part 2)',
#  'Honey Honey (Part 1)',
#  'Fight Companion',
#  'Christopher Ryan',
#  'Lewis, from Unbox Therapy',
#  'Sebastian Maniscalco',
#  'Jane McGonigal',
#  'Jay Leno',
#  'Tom Segura',
#  'Bryan Callen',
#  'Ronda Rousey & Edmond Tarverdyan',
#  'Abby Martin',
#  'Brian Redban',
#  'Justin Wren',
#  'Fight Companion',
#  'Jeff Ross',
#  'Jeff Novitzky',
#  'Brian Redban',
#  'Ethan Nadelmann',
#  'Mark & Chris Bell',
#  'Gad Saad',
#  'Fight Companion',
#  'Steven Hassan',
#  'Barry Crimmins & Bobcat Goldthwait',
#  'Jonathan Ward',
#  'Josh Zepps',
#  'Esther Ku',
#  'Kirik Jenness & Chris Palmquist',
#  'Brian Redban',
#  'Nick DiPaolo & Adam Lowery',
#  'Dr. Rhonda Patrick',
#  'Fight Companion',
#  'Brendan Schaub & Bryan Callen',
#  'Michael A. Wood, Jr.',
#  'Jon Ronson',
#  'Jim Norton',
#  'Jim Florentine',
#  'Kurt Metzger',
#  'Duncan Trussell',
#  'Neal Brennan',
#  'Tom Segura & Christina Pazsitzky',
#  'Dominic Monaghan',
#  'Fight Companion',
#  'Vinny Shoreman',
#  'Rutledge Wood',
#  'Dean Delray',
#  'Greg Fitzsimmons',
#  'Corey Knowlton',
#  'Bryan Callen',
#  'Kevin Folta',
#  'Rich Vos',
#  'Natasha Leggero',
#  'Ricky Schroder',
#  'Jordan Gilbert (c9n0thing)',
#  'Nick Curson',
#  'Jonathan Gottschall',
#  'Fight Companion',
#  'Fight Companion',
#  'Adam Scorgie',
#  'Dom Irrera',
#  'Dr. Dan Engle & Aubrey Marcus',
#  'Joe Schilling',
#  'Brad Williams',
#  '"Big" Jay Oakerson',
#  'Rich Roll',
#  'Sam Harris',
#  'Greg Proops',
#  'Charles C. Johnson',
#  'Aubrey de Grey',
#  'Remi Warren',
#  'Bryan Callen',
#  'Abby Martin',
#  'Alex Winter',
#  'Fight Companion',
#  'Fight Companion',
#  'Les Stroud',
#  'Josh Barnett',
#  'Duncan Trussell',
#  'Andrew Hill, PhD',
#  'Garry Tonon & Eddie Bravo',
#  'Tony Hinchcliffe',
#  'Jim Norton',
#  'Tom Papa',
#  'Ari Shaffir',
#  'Katy Bowman',
#  'Ari Shaffir & Duncan Trussell',
#  'Justin Wren',
#  'Eddie Huang & Randall Park',
#  'Barry Rothbart',
#  'Randall Carlson',
#  'Joe Schilling',
#  'Ali Rizvi',
#  'Tom Segura',
#  'Brian Cox',
#  'Bryan Callen & Brendan Schaub',
#  'Joey Diaz',
#  'Trevor Moore',
#  'Josh McDermitt',
#  'Ari Shaffir',
#  'Adam Carolla',
#  'Aubrey Marcus',
#  'Bert Kreischer',
#  'Steve Maxwell',
#  'Artie Lange',
#  'Brian Regan',
#  'John Wayne Parr',
#  'Greg Fitzsimmons',
#  'Christopher Ryan, PhD',
#  'Ms. Pat',
#  'Billy Corben',
#  'David Choe',
#  'Matt Farah, Tod Mesirow',
#  'Rick Doblin',
#  'Mariana van Zeller',
#  'Joey "CoCo" Diaz',
#  'Marc Maron',
#  'Shane Smith',
#  'Bryan Callen',
#  'Duncan Trussell',
#  'Duane Ludwig, TJ Dillashaw',
#  'Greg Fitzsimmons',
#  'David Seaman',
#  'Ian McCall',
#  'Mac Lethal',
#  'Joey "CoCo" Diaz',
#  'Everlast',
#  'Stefan Molyneux',
#  'Tom Segura',
#  'Jason Silva, Duncan Trussell, Ari Shaffir',
#  'Abby Martin',
#  'Aubrey Marcus',
#  'Bobcat Goldthwait',
#  'Buck Angel',
#  'Georges St. Pierre',
#  'Tom Segura',
#  'Ari Shaffir, Amy Schumer',
#  'Dom Irrera',
#  'Dan Hardy',
#  'Daniele Bolelli',
#  'Bert Kreischer',
#  'Alex Grey',
#  'Graham Hancock',
#  'Dave Asprey, Tait Fletcher',
#  'Eddie Ifft',
#  'Everlast',
#  'Kelly Starrett, Glen Cordoza',
#  'Sam Tripoli',
#  'Fight Companion',
#  'Fight Companion',
#  'Bryan Callen',
#  'Ari Shaffir',
#  'Joey Diaz',
#  'Amy Schumer',
#  'Matt Paxton',
#  'Jason Silva',
#  'Jim Gaffigan',
#  'Sam Harris',
#  'Greg Fitzsimmons',
#  '',
#  'Daniele Bolelli',
#  'Ari Shaffir',
#  'Tom Segura',
#  'DEADMAU5, Russell Peters, Eddie Bravo',
#  'Peter Joseph',
#  'Ari Shaffir',
#  'Bryan Callen',
#  'EverLast (Part 1)',
#  'Hamilton Morris',
#  '',
#  ...]

# %%
len(guest_names)
# Out:
# 1324

# %%
unique_names = list(set(guest_names))
print(len(unique_names))
print(unique_names)
# Out:
# 756
# ['', 'Cmdr. David Fravor & Jeremy Corbell', 'Dr. Phil', 'Annie Lederman', 'Andy Dick', 'Tony Hinchcliffe (Audio Only)', 'Anthony Jeselnik', 'Sam Sheridan', 'Steve Sweeney', 'Sean Carroll', 'Ian Edwards', 'Aubrey Marcus', 'Wheeler Walker, Jr.', 'Steven Crowder', 'Dominic Monaghan', 'Mike Schmidt', 'Dan Auerbach', 'Brendon Walsh (Part 3)', 'Rob Lowe', 'Justin Wren & Rafael Lovato Jr.', 'Joe De Sena', 'Rashad Evans', 'Steven Pressfield, Aubrey Marcus', 'Ari Shaffir & John Heffron (Part 2)', 'Alexis Ohanian', 'Tim Kennedy', 'Ron Funches', 'Ms. Pat', "Chris D'Elia", 'Larry Sharpe', 'Shannon Briggs', 'Steve Schirripa', 'Adam Cropp', 'JRE MMA Show #1', 'Bruce Lipton PHD (PART ONE)', 'Daryl Wright & Brian Whitaker', 'Banachek', 'Andre Ward', 'Doug Stanhope & Joey Diaz', 'Ralphie May', 'Erik Griffin', 'Kurt Metzger', 'Mike Baker', 'Peter Attia', 'Todd Glass', 'Dana Dearmond', 'Joey Diaz (Part 3)', 'Richard Dawkins', 'Mark Sisson', 'John Kavanagh & George Lockhart', 'Michael A. Wood, Jr.', 'Mikhaila Peterson', 'Steven Hassan', 'Dave Rubin', 'RZA & Donnell Rawlings', 'Chris Aubrey Marcus (Part 2)', 'Nick Bostrom', 'John Carmack', 'Dave Smith', 'Dan Hardy', 'Rob Zombie', 'James Lindsay', 'Mark & Chris Bell', 'Timothy Denevi', 'Dr. Ben Goertzel', 'Cameron Hanes', 'Jorge Masvidal', 'Sturgill Simpson & His Band', 'Molly Crabapple', 'Michelle Waterson', 'Jack Dorsey', 'Tony Hinchcliffe', 'Frankie Edgar', 'Freddy Lockhart (Part 1)', 'Mike Dolce, Joey Diaz', 'Dan Savage', 'Henry Cejudo & Eric Albarracin', 'Trevor Valle', 'Chris Stapleton', 'Ari Shaffir (Part 1)', 'Eddie Bravo (Part 1)', 'Katy Bowman', 'Nina Teicholz', 'Joey Diaz (Part 4)', 'Naval Ravikant', 'Kill Tony Cast', 'Danica Patrick', 'Peter Boghossian & James Lindsay', 'Kyle Kingsbury', 'Christopher Ryan', 'Rich Vos', 'Christina Sommers', 'Rory Albanese', 'William von Hippel', 'Joey Diaz, Eddie Bravo (Part 1)', 'Andrew Schulz', 'Doug Stanhope & Tom Rhodes', 'Whitney Cummings & Annie Lederman', 'Brian Grazer', 'Freddy Lockhart (Part 2)', 'Maynard James Keenan', 'Joe Rogan', 'Peter Schiff', 'Ben Greenfield', 'Peter Giuliano', 'Ryan Parsons', 'TJ English & Joey Diaz', 'Nimesh Patel', 'Mariana van Zeller', 'Peter McGraw', 'Remi Warren', 'Liz Phair', 'Henry Rollins', 'Paul Stamets', 'Neal Brennan', 'Georges St. Pierre', 'Tim Pool', 'Billy Corben', 'Miley Cyrus', 'Douglas Rushkoff', 'Ben Askren', 'Joe Rogan Experience #205  Neal Brennan', 'Robert Oberst', 'Ben Anderson', 'Dr. Bradley Garrett', 'Jenny Johnson', 'Ioan Grillo', 'Morgan Fallon', 'Kelly Pavlik', 'B', 'Gary Johnson', 'Barbara Freese', 'Barry Rothbart', 'Crash, from Float Lab', 'Graham Hancock', 'Matthew Walker', 'Joe Quirk', 'Josh Fox', 'Bobcat Goldthwait', 'Henry Cejudo', 'Eddie Huang', 'Cat Zingano', 'Stefan Molyneux', 'Miriam Nakamoto', 'Dave Foley & Paul Greenberg', 'Carlos Condit & Erwan Le Corre', 'Tommy Chong', 'Dean Delray', 'Joey "CoCo" Diaz, Duncan Trussell', 'Macaulay Culkin', 'David Lee Roth', 'Fight Breakdown', 'Jon Reep', 'Jeremy Stephens, Eddie Bravo', 'Chris Kresser & Dr. Joel Kahn', 'Lex Fridman', 'TJ Dillashaw, Duane Ludwig & Bas Rutten', 'Bernie Sanders', 'Anthony Cumia', 'Nick Cutter', 'Brendan Schaub & Fight Companion ? (Part 2)', 'Eddie Huang & Randall Park', 'Giorgio A. Tsoukalos, Eddie Bravo', 'David Blaine', 'Abby Martin', 'C.T. Fletcher', 'Joe Rogan Experience #206  Eddie Bravo', 'Josh Olin', 'Sober October 2 Recap', 'Geoffrey Miller', 'Joe DeRosa', 'Ms Pat', 'Gavin McInnes', 'Kevin Folta', 'Kelly Starrett, Glen Cordoza', 'Steven Tyler', 'Owen Benjamin', 'Gad Saad', 'Jay Leno', 'Joe List', 'Marques Brownlee', 'Dave Asprey, Tait Fletcher', 'Aljamain Sterling', 'Zuby', 'Lindsey Fitzharris', 'Aubrey de Grey', 'Lawrence Lessig', 'Whitney Cummings', 'Dr. Cornel West', 'John Anthony West', 'Chael Sonnen', 'Roy Wood Jr', 'Peter Boghossian', 'Rutledge Wood', 'Tulsi Gabbard', 'Kyle Dunnigan', 'Rickson Gracie & Eddie Bravo', 'JD & John Witherspoon', 'Aubrey Marcus (Part 1)', 'Trevor Moore', 'Russell Peters', 'Brian ...

# %%
# Delete the ' ' names
unique_names = set()
for name in guest_names:
    if len(name) > 1:
        unique_names.add(name)


unique_names = list(unique_names)
len(unique_names)
# Out:
# 754

# %%
print(len(names_from_description))
print(names_from_description)
# Out:
# 2011
# ['Ron White', 'Adam Curry', 'Mike Tyson', 'Hotboxin', 'Mike Tyson', 'Tyson', 'Miley Cyrus', 'Duncan Trussell', 'Annie Lederman', '@Annie Lederman', 'Nikki Glaser', 'Nikki Glaser', 'Nikki Glaser', 'David Blaine', '@David Blaine', 'Ali Macofsky', '@Ali Macofsky', 'Tim Dillon', 'Ron Funches', 'Joey', 'Diaz', 'Joey', 'Diaz \nBrian Redban', 'Deathsquad', 'Tony', '
# %% [markdown]
# **Guest Co-Appearance Network:**
#
# * Nodes: Guests.
# * Edges: Connect two guests if they have appeared together in an episode.
# * Use: To see which guests frequently appear together.

# %%
import networkx as nx
import itertools

def create_coappearance_network(guest_names):
    G = nx.Graph()
    
    for names in guest_names:
        # Assuming guests are separated by commas
        guests = names.split(',')
        
        # Remove any extra whitespace
        guests = [guest.strip() for guest in guests if len(guest.strip()) > 1]
        
        # Add edges for every pair of guests
        for guest1, guest2 in itertools.combinations(guests, 2):
            if G.has_edge(guest1, guest2):
                # Increment weight by 1 if edge already exists
                G[guest1][guest2]['weight'] += 1
            else:
                G.add_edge(guest1, guest2, weight=1)
                    
    return G

# Create the network using your guest_names
G = create_coappearance_network(guest_names)

# For visualization
import matplotlib.pyplot as plt
plt.figure(figsize=(12,12))
pos = nx.spring_layout(G, seed=42)  # Seed for reproducible layout
nx.draw_networkx_nodes(G, pos)
nx.draw_networkx_edges(G, pos)
nx.draw_networkx_labels(G, pos)
plt.show()

# %%
multi_guest_episodes = [names for names in guest_names if ',' in names]
print(multi_guest_episodes)
# Out:
# ['Forrest Griffin, Clint Wattenberg & Dr. Duncan French', 'Jack Dorsey, Vijaya Gadde & Tim Pool', 'Stanley Krippner, Christopher Ryan', 'Steven Rinella, Bryan Callen, Cam Edwards', 'Steve Rinella, Bryan Callen', 'Enson Inoue, Chuck Lidell', 'David Choe, Yoshi Obayashi', 'Mike Dolce, Joey Diaz', 'Tom Segura, Christina Pazsitzky', 'Ari Shaffir, Bert Kreischer & Tom Segura', 'Ari Shaffir, Bert Kreischer & Tom Segura', 'TJ Dillashaw, Duane Ludwig & Bas Rutten', 'Gino & AJ, from Speedweed', 'Michael Wood, Jr.', 'Lewis, from Unbox Therapy', 'Wheeler Walker, Jr.', 'Ian McCall, Brendan Schaub & Bryan Callen', 'Gary Clark, Jr.', 'Kip Andersen & Keegan Kuhn, producers of Cowspiracy', 'Lewis, from Unbox Therapy', 'Michael A. Wood, Jr.', 'Andrew Hill, PhD', 'Christopher Ryan, PhD', 'Matt Farah, Tod Mesirow', 'Duane Ludwig, TJ Dillashaw', 'Jason Silva, Duncan Trussell, Ari Shaffir', 'Ari Shaffir, Amy Schumer', 'Dave Asprey, Tait Fletcher', 'Kelly Starrett, Glen Cordoza', 'DEADMAU5, Russell Peters, Eddie Bravo', 'Joey Diaz, Eddie Bravo, Denny Prokopos', 'Tom Segura, Christina Pazsitzky', 'Graham Hancock, Duncan Trussell', 'Giorgio A. Tsoukalos, Eddie Bravo', 'Lewis, from Unbox Therapy', 'Dr. Mark Gordon, Matthew Gosney & Jason Hall', 'Vince & Emily Horn, from Buddhist Geeks', 'Michael Stevens, from VSauce', 'Lewis, from Unbox Therapy', 'Crash, from Float Lab', 'Crash, from Float Lab (Part 2)', 'Lewis, from Unbox Therapy', 'Duncan Trussell, Christopher Ryan', 'Robert Greene, Aubrey Marcus', 'Jeremy Stephens, Eddie Bravo', 'Steven Pressfield, Aubrey Marcus', 'Dan Carlin, Daniele Bolelli', 'Tom Segura, Christina Pazsitzky', 'Joey "CoCo" Diaz, Duncan Trussell', 'Ari Shaffir, Eddie Bravo', 'Joey Diaz, Eddie Bravo (Part 2)', 'Joey Diaz, Eddie Bravo (Part 1)']

# %%
import networkx as nx

G = nx.Graph()

# Iterate over each episode's guest list
for names in guest_names:
    # Split by comma first
    guests = [name.strip() for name in names.split(',')]
    
    # Check if we need further splitting by "&"
    all_guests = []
    for guest in guests:
        if '&' in guest:
            all_guests.extend([name.strip() for name in guest.split('&')])
        else:
            all_guests.append(guest)
    
    # Create edges for every pair of guests in the episode
    for i in range(len(all_guests)):
        for j in range(i+1, len(all_guests)):
            # If edge already exists, increase the weight by 1
            if G.has_edge(all_guests[i], all_guests[j]):
                G[all_guests[i]][all_guests[j]]['weight'] += 1
            else:
                G.add_edge(all_guests[i], all_guests[j], weight=1)

# Visualization
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_size=3000, node_color="skyblue", font_size=10, width=[G[u][v]['weight'] for u,v in G.edges()])
plt.title("Guest Co-Appearance Network")
plt.show()

# %% [markdown]
# This gives a graph showing which guests appeared together and how frequently.

# %% [markdown]
# **Guest-Topic Network:**
#
# * Nodes: Guests and extracted topics or keywords from descriptions.
# * Edges: Connect a guest to a topic if that topic is mentioned in an episode where the guest appeared.
# * Use: To see the topics associated with each guest.

# %%
import networkx as nx

G = nx.Graph()

# Extract topics from descriptions
def extract_topics(description):
    doc = nlp(description)
    # We'll consider entities of type 'ORG', 'NORP', 'FAC', 'GPE', 'LOC', 'PRODUCT', 'EVENT', 'WORK_OF_ART', 'LAW', 'LANGUAGE' as potential topics
    return [entity.text for entity in doc.ents if entity.label_ in ['ORG', 'NORP', 'FAC', 'GPE', 'LOC', 'PRODUCT', 'EVENT', 'WORK_OF_ART', 'LAW', 'LANGUAGE']]

# Create nodes and edges
for episode in data:
    guests = [name.strip() for name in episode['guest'].split(',')]
    topics = extract_topics(episode['description'])
    
    # For bipartite networks, you often need to specify the node type
    for guest in guests:
        G.add_node(guest, node_type='guest')
        
    for topic in topics:
        G.add_node(topic, node_type='topic')
        
    for guest in guests:
        for topic in topics:
            G.add_edge(guest, topic)

# Visualization
plt.figure(figsize=(12,12))

# Separate the guest and topic nodes for visualization
guest_nodes = [n for n, d in G.nodes(data=True) if d['node_type']=='guest']
topic_nodes = [n for n, d in G.nodes(data=True) if d['node_type']=='topic']

# Use a shell layout with guests in the middle and topics surrounding them
pos = nx.shell_layout(G, [topic_nodes, guest_nodes])

nx.draw_networkx_nodes(G, pos, nodelist=guest_nodes, node_color="skyblue", node_size=500)
nx.draw_networkx_nodes(G, pos, nodelist=topic_nodes, node_color="lightgreen", node_size=500)
nx.draw_networkx_edges(G, pos)
nx.draw_networkx_labels(G, pos, font_size=10)

plt.title("Guest-Topic Network")
plt.show()

# %% [markdown]
# **Guest Popularity Network:**
#
# * Nodes: Guests.
# * Edges: Connect a guest to another based on a metric like the number of views or likes (if you have that data).
# * Use: To understand which guests are the most popular or influential.

# %% [markdown]
# If two guests appear together multiple times, their edge weight gets updated.
#
# The edge widths in the visualization are scaled for better visuals.

# %%
# Check if 'views' field exists in the first episode of the data
if 'views' in data[0]:
    print("The 'views' field exists in the data.")
else:
    print("The 'views' field does not exist in the data.")
# Out:
# The 'views' field exists in the data.

# %%
import networkx as nx

# Create an empty weighted graph
G = nx.Graph()

# Iterate over the data to add nodes for each guest and weighted edges based on views
for episode in data:
    guests = [name.strip() for name in episode['guest'].split(',')]
    
    # Consider every pair of guests in the episode
    for i in range(len(guests)):
        for j in range(i+1, len(guests)):
            guest1, guest2 = guests[i], guests[j]
            
            # Convert views to integer
            views = int(episode['views'].replace(',', ''))

            
            # If both guests are already connected, update the edge weight
            if G.has_edge(guest1, guest2):
                G[guest1][guest2]['weight'] += views
            else:
                G.add_edge(guest1, guest2, weight=views)



# Visualization
plt.figure(figsize=(12,12))
edge_widths = [d['weight'] / 1000000 for _, _, d in G.edges(data=True)] # This scales the view count for better visualization
pos = nx.spring_layout(G)
nx.draw_networkx_nodes(G, pos, node_color="skyblue", node_size=1000)
nx.draw_networkx_edges(G, pos, width=edge_widths)
nx.draw_networkx_labels(G, pos, font_size=10)

plt.title("Guest Popularity Network")
plt.show()

# %% [markdown]
# **Now lets do some clustering ideas.**

# %% [markdown]
# Community Detection: Identify clusters or communities within the network.
# Use Louvain algorythm to group nodes that are more connected together than with the rest of the network.

# %%
# !pip install python-louvain

# %%
import community as community_louvain

# Use the Louvain algorithm to detect communities
partition = community_louvain.best_partition(G)

# Visualize the communities
pos = nx.spring_layout(G)
plt.figure(figsize=(10, 10))
plt.axis('off')
nx.draw_networkx_nodes(G, pos, node_size=600, cmap=plt.cm.RdYlBu, node_color=list(partition.values()))
nx.draw_networkx_edges(G, pos, alpha=0.3)
plt.show()

# Print the communities
for community_num, nodes in enumerate(partition):
    print(f"Community {community_num}: {nodes}")
# Out:
# Community 0: Forrest Griffin
# Community 1: Clint Wattenberg & Dr. Duncan French
# Community 2: Jack Dorsey
# Community 3: Vijaya Gadde & Tim Pool
# Community 4: Stanley Krippner
# Community 5: Christopher Ryan
# Community 6: Steven Rinella
# Community 7: Bryan Callen
# Community 8: Cam Edwards
# Community 9: Steve Rinella
# Community 10: Enson Inoue
# Community 11: Chuck Lidell
# Community 12: David Choe
# Community 13: Yoshi Obayashi
# Community 14: Mike Dolce
# Community 15: Joey Diaz
# Community 16: Tom Segura
# Community 17: Christina Pazsitzky
# Community 18: Ari Shaffir
# Community 19: Bert Kreischer & Tom Segura
# Community 20: TJ Dillashaw
# Community 21: Duane Ludwig & Bas Rutten
# Community 22: Gino & AJ
# Community 23: from Speedweed
# Community 24: Michael Wood
# Community 25: Jr.
# Community 26: Lewis
# Community 27: from Unbox Therapy
# Community 28: Wheeler Walker
# Community 29: Ian McCall
# Community 30: Brendan Schaub & Bryan Callen
# Community 31: Gary Clark
# Community 32: Kip Andersen & Keegan Kuhn
# Community 33: producers of Cowspiracy
# Community 34: Michael A. Wood
# Community 35: Andrew Hill
# Community 36: PhD
# Community 37: Matt Farah
# Community 38: Tod Mesirow
# Community 39: Duane Ludwig
# Community 40: Jason Silva
# Community 41: Duncan Trussell
# Community 42: Amy Schumer
# Community 43: Dave Asprey
# Community 44: Tait Fletcher
# Community 45: Kelly Starrett
# Community 46: Glen Cordoza
# Community 47: DEADMAU5
# Community 48: Russell Peters
# Community 49: Eddie Bravo
# Community 50: Denny Prokopos
# Community 51: Graham Hancock
# Community 52: Giorgio A. Tsoukalos
# Community 53: Dr. Mark Gordon
# Community 54: Matthew Gosney & Jason Hall
# Community 55: Vince & Emily Horn
# Community 56: from Buddhist Geeks
# Community 57: Michael Stevens
# Community 58: from VSauce
# Community 59: Crash
# Community 60: from Float Lab
# Community 61: from Float Lab (Part 2)
# Community 62: Robert Greene
# Community 63: Aubrey Marcus
# Community 64: Jeremy Stephens
# Community 65: Steven Pressfield
# Community 66: Dan Carlin
# Community 67: Daniele Bolelli
# Community 68: Joey "CoCo" Diaz
# Community 69: Eddie Bravo (Part 2)
# Community 70: Eddie Bravo (Part 1)

# %% [markdown]
# Lets use an other algorythm: Girvan-Newman

# %%
from networkx.algorithms.community import girvan_newman

# Girvan-Newman algorithm to detect communities
communities = girvan_newman(G)

# Get the first partitioning (you can also explore deeper levels)
first_communities = next(communities)

# Print the communities
for community_num, community in enumerate(first_communities):
    print(f"Community {community_num}: {community}")
# Out:
# Community 0: {'Clint Wattenberg & Dr. Duncan French', 'Forrest Griffin'}
# Community 1: {'Jack Dorsey', 'Vijaya Gadde & Tim Pool'}
# Community 2: {'Graham Hancock', 'Christopher Ryan', 'Stanley Krippner', 'Bert Kreischer & Tom Segura', 'Amy Schumer', 'Jason Silva', 'Duncan Trussell', 'Andrew Hill', 'Ari Shaffir', 'PhD', 'Joey "CoCo" Diaz'}
# Community 3: {'Cam Edwards', 'Bryan Callen', 'Steven Rinella', 'Steve Rinella'}
# Community 4: {'Chuck Lidell', 'Enson Inoue'}
# Community 5: {'Yoshi Obayashi', 'David Choe'}
# Community 6: {'Eddie Bravo (Part 1)', 'Eddie Bravo (Part 2)', 'Mike Dolce', 'Jeremy Stephens', 'Denny Prokopos', 'Eddie Bravo', 'Joey Diaz', 'Russell Peters', 'DEADMAU5', 'Giorgio A. Tsoukalos'}
# Community 7: {'Tom Segura', 'Christina Pazsitzky'}
# Community 8: {'Duane Ludwig', 'Duane Ludwig & Bas Rutten', 'TJ Dillashaw'}
# Community 9: {'Gino & AJ', 'from Speedweed'}
# Community 10: {'Michael A. Wood', 'Gary Clark', 'Michael Wood', 'Jr.', 'Wheeler Walker'}
# Community 11: {'from Unbox Therapy', 'Lewis'}
# Community 12: {'Ian McCall', 'Brendan Schaub & Bryan Callen'}
# Community 13: {'producers of Cowspiracy', 'Kip Andersen & Keegan Kuhn'}
# Community 14: {'Matt Farah', 'Tod Mesirow'}
# Community 15: {'Tait Fletcher', 'Dave Asprey'}
# Community 16: {'Glen Cordoza', 'Kelly Starrett'}
# Community 17: {'Matthew Gosney & Jason Hall', 'Dr. Mark Gordon'}
# Community 18: {'Vince & Emily Horn', 'from Buddhist Geeks'}
# Community 19: {'from VSauce', 'Michael Stevens'}
# Community 20: {'Crash', 'from Float Lab (Part 2)', 'from Float Lab'}
# Community 21: {'Aubrey Marcus', 'Steven Pressfield', 'Robert Greene'}
# Community 22: {'Daniele Bolelli', 'Dan Carlin'}
